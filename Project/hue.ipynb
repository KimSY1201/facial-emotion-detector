# %%
# %pip install koreanize_matplotlib
# Out:
# ...
#   Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# ...
# Using cached koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

# CSV 불러오기 (평균 HSV 포함된 파일)
df = pd.read_csv(r"C:\Users\KDT-37\Desktop\KDT_7\09_ML_CV\Project\보라_crop_std_output.csv")

# H_avg 컬럼 시각화
plt.figure(figsize=(10, 5))
plt.hist(df['H_avg'], bins=30, color='orchid', edgecolor='black')
plt.title('Hue (H_avg) 분포')
plt.xlabel('Hue Value (0~179, OpenCV 기준)')
plt.ylabel('이미지 개수')
plt.grid(True)
plt.show()
